# %%
import matplotlib.pyplot as plt
import seaborn as sns
#purpose of inline is that our graphs should not be shown in pop ups
# %matplotlib inline

# %% [markdown]
# #Line charts

# %%
apples=[0.895,0.91,0.919,0.926,0.929,0.931]
plt.plot(apples)

# %%
years=[2010,2011,2012,2013,2014,2015]
plt.plot(years,apples)
plt.xlabel('Years')
plt.ylabel('Apples');

# %%
years=range(2000,2012)
apples=[0.895,0.91,0.919,0.926,0.929,0.931,0.934,0.936,0.937,0.9375,0.9372,0.9393]
oranges=[0.962,0.941,0.930,0.923,0.918,0.908,0.907,0.904,0.901,0.898,0.9,0.896]
plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel('years')
plt.ylabel('Yield')
plt.title('Yields in Kanto')
plt.legend(['apples','oranges']);

# %%
plt.plot(years,apples, marker='o')
plt.plot(years,oranges, marker='x')
plt.xlabel('years')
plt.ylabel('Yield')
plt.title('Yields in Kanto')
plt.legend(['apples','oranges']);

# %%
plt.plot(years,apples, 'x-b')
plt.plot(years,oranges, 'o--r')
plt.xlabel('years')
plt.ylabel('Yield')
plt.title('Yields in Kanto')
plt.legend(['apples','oranges']);

# %%
plt.figure(figsize=(5,5))
plt.plot(years,oranges,'o-r')

# %%
sns.set_style('darkgrid')

plt.plot(years,apples, 'x-b')
plt.plot(years,oranges, 'o--r')
plt.xlabel('years')
plt.ylabel('Yield')
plt.title('Yields in Kanto')
plt.legend(['apples','oranges']);

# %%
import matplotlib

# %%
plt.plot(years,apples, 'x-b')
plt.plot(years,oranges, 'o--r')
plt.xlabel('years')
plt.ylabel('Yield')
plt.title('Yields in Kanto')
plt.legend(['apples','oranges']);

# %%
matplotlib.rcParams['font.size']=14
matplotlib.rcParams['figure.figsize']=(15,4)

# %% [markdown]
# #Scatter plot

# %%
flowers_df=sns.load_dataset('iris')
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#with this data we could not find any particular insight so we need to plot scatterplot
plt.plot(flowers_df.sepal_length,flowers_df.sepal_width)

# %%
sns.scatterplot(flowers_df.sepal_length,flowers_df.sepal_width)

# %%
sns.scatterplot(flowers_df.sepal_length,
                flowers_df.sepal_width,
               hue=flowers_df.species,
               s=100)

# %% [markdown]
# #Histogram

# %%
flowers_df=sns.load_dataset('iris')
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.hist(flowers_df.sepal_width);

# %%
plt.hist(flowers_df.sepal_width, bins=5);

# %%
setosa_df=flowers_df[flowers_df.species=='setosa']
verginica_df=flowers_df[flowers_df.species=='verginica']
versicolor_df=flowers_df[flowers_df.species=='versicolor']

# %%
import numpy as np
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25));

plt.legend(['setosa','versicolor'])

# %%
import numpy as np
plt.hist([setosa_df.sepal_width,versicolor_df.sepal_width,verginica_df.sepal_width],
          bins=np.arange(2,5,0.25),
         stacked=True)
# Out:
# ([array([ 0.,  1.,  0.,  1., 15., 11., 12.,  6.,  3.,  1.,  0.]),
#   array([ 3.,  7., 12., 14., 29., 13., 12.,  6.,  3.,  1.,  0.]),
#   array([ 3.,  7., 12., 14., 29., 13., 12.,  6.,  3.,  1.,  0.])],
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#         4.75]),
#  <a list of 3 Lists of Patches objects>)

# %% [markdown]
# #Bar charts

# %%
years=[2000,2001,2002,2003,2004,2005]
apples=[0.35,0.6,0.9,0.8,0.65,0.8]
oranges=[0.4,0.8,0.9,0.7,0.6,0.8]

# %%
plt.bar(years,oranges)
plt.plot(years,oranges, 'o--r');

# %%
plt.bar(years,apples)
plt.bar(years,oranges,bottom=apples);

# %%
tips_df=sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df_group=tips_df.groupby('day')[['total_bill']].mean()
tips_df_group
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
#is ma day itself day nai ha wo index ha
tips_df_group.index
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, name='day', dtype='category')

# %%
plt.bar(tips_df_group.index,tips_df_group.total_bill)
# Out:
# <BarContainer object of 4 artists>

# %%
sns.barplot('day','total_bill', data=tips_df)

# %%
sns.barplot('day','total_bill',hue='sex', data=tips_df)

# %%
#axis changed
sns.barplot('total_bill','day',hue='sex', data=tips_df)

# %% [markdown]
# #HeatMap

# %%
#in heatmap we need a matrix tu build we could achive this by pivot
flights_df=sns.load_dataset('flights').pivot('month','year','passengers')

# %%
sns.heatmap(flights_df)

# %%
sns.heatmap(flights_df,fmt='d',annot=True,cmap='Blues')

# %% [markdown]
# #displaying images using matplotlib

# %%
from urllib.request import urlretrieve
urlretrieve('https://i.imgur.com/SkPbq.jpg','chart.jpg')
# Out:
# ('chart.jpg', <http.client.HTTPMessage at 0x8b6e12b08>)

# %%
from PIL import Image

# %%
img=Image.open('chart.jpg')

# %%
plt.imshow(img)

# %%
#we know that the image are made by the help of the arrays because it had pixels
img_array=np.array(img)

# %%
img_array.shape
# Out:
# (481, 640, 3)

# %%
plt.grid(False)
plt.axis('off')
plt.title('Data')
plt.imshow(img)

# %% [raw]
# # Plotting multiple charts in a grid

# %%
fig,axes=plt.subplots(2,3, figsize=(16,9))

#using these axes
axes[0,0].plot(years,apples,'s-r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Amount')
axes[0,0].set_title('Yields')

#using the axes to plot the scatterplot

axes[0,1].set_title('Barplot')
sns.scatterplot(flowers_df.sepal_length,flowers_df.sepal_width,
               hue=flowers_df.species,
               s=100,
               ax=axes[0,1])

#using the axes to plot the barplot
axes[0,2].set_title('barplot')
sns.barplot('day','total_bill',data=tips_df,
           ax=axes[0,2])
